# %%
import pandas as pd
import scipy.stats as stats
import statsmodels.formula.api as smf
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

def pre_process(df, keep_cols=None):
    if keep_cols is None:
        keep_cols = df.columns
    df_selected = df[keep_cols].dropna().copy()

    numeric_cols = df_selected.select_dtypes(include=['number']).columns.tolist()
    categorical_cols = df_selected.select_dtypes(exclude=['number']).columns.tolist()

    preprocessor = ColumnTransformer(
        transformers=[
            ('numeric', StandardScaler(), numeric_cols),
            ('categorical', OneHotEncoder(drop='first', sparse_output=False), categorical_cols)
        ]
    )

    transformed_array = preprocessor.fit_transform(df_selected)

    feature_names = []
    if numeric_cols:
        feature_names.extend(numeric_cols)
    if categorical_cols:
        cat_features = preprocessor.named_transformers_['categorical'].get_feature_names_out(categorical_cols)
        feature_names.extend(cat_features)

    preprocessed_df = pd.DataFrame(transformed_array, columns=feature_names, index=df_selected.index)

    return preprocessed_df

# %%
# ENGLISH
# ----------------------------------------------------------------------------------------------------
# load df
df_EN = pd.read_csv('./data/regression_data_EN.csv')

# define baselines and covariates studied
BASELINE_EN = '1 + Length + LgSUBTLWF + OLD + LgSUBTLWF:Length + LgSUBTLWF:OLD'
COVARIATES = ['n_communities', 'entropy', 'max_dom', 'dissimilarity', 'ambiguity_binary', 'ambiguity']

# baseline
baseline_formula = 'log_rt ~ ' + BASELINE_EN
preprocessed_df = pre_process(df_EN, ['log_rt', 'Length', 'LgSUBTLWF', 'OLD'])
baseline_model = smf.ols(baseline_formula, data=preprocessed_df).fit()

report = f"""
--------------------------------------------------------------------
Covariate: None (Baseline model)
Likelihood Ratio Test Statistic (p-value)': N/A
AIC: {baseline_model.aic:.0f}
BIC: {baseline_model.bic:.0f}
--------------------------------------------------------------------
"""
print(report)
print(baseline_model.summary())
print('\n\n')

for covariate in COVARIATES:
    preprocessed_df = pre_process(df_EN, ['log_rt', 'Length', 'LgSUBTLWF', 'OLD', covariate])
    
    # expanded: baseline + covariate
    expanded_formula = 'log_rt ~ ' + BASELINE_EN + ' + ' + covariate
    expanded_model = smf.ols(expanded_formula, data=preprocessed_df).fit()

    lr_stat = 2 * (expanded_model.llf - baseline_model.llf)
    dof = 1 # difference between expanded and baseline model is 1 covariate
    p_value = 1 - stats.chi2.cdf(lr_stat, dof)

    report = f"""
--------------------------------------------------------------------
Covariate: {covariate}
Likelihood Ratio Test Statistic (p-value)': {lr_stat:.1f} ({p_value:.3f})
AIC: {expanded_model.aic:.0f}
BIC: {expanded_model.bic:.0f}
--------------------------------------------------------------------
        """
    print(report)
    print(expanded_model.summary())
    print('\n\n')
# Out:
# --------------------------------------------------------------------
# Covariate: None (Baseline model)
# Likelihood Ratio Test Statistic (p-value)': N/A
# AIC: 15353
# BIC: 15394
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     1087.
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:18:25   Log-Likelihood:                -7670.4
# No. Observations:                6815   AIC:                         1.535e+04
# Df Residuals:                    6809   BIC:                         1.539e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0116      0.010     -1.208      0.227      -0.030       0.007
# Length               0.2763      0.019     14.462      0.000       0.239       0.314
# LgSUBTLWF           -0.4125      0.010    -40.209      0.000      -0.433      -0.392
# OLD                  0.1422      0.020      7.281      0.000       0.104       0.181
# LgSUBTLWF:Length     0.0371      0.021      1.781      0.075      -0.004       0.078
# LgSUBTLWF:OLD       -0.0697      0.021     -3.257      0.001      -0.112      -0.028
# ==============================================================================
# Omnibus:                      129.294   Durbin-Watson:                   1.836
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              136.492
# Skew:                           0.338   Prob(JB):                     2.30e-30
# Kurtosis:                       3.155   Cond. No.                         5.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# --------------------------------------------------------------------
# Covariate: n_communities
# Likelihood Ratio Test Statistic (p-value)': 3.9 (0.050)
# AIC: 15351
# BIC: 15399
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     906.9
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:18:25   Log-Likelihood:                -7668.5
# No. Observations:                6815   AIC:                         1.535e+04
# Df Residuals:                    6808   BIC:                         1.540e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0117      0.010     -1.215      0.224      -0.031       0.007
# Length               0.2737      0.019     14.300      0.000       0.236       0.311
# LgSUBTLWF           -0.4112      0.010    -40.014      0.000      -0.431      -0.391
# OLD                  0.1445      0.020      7.383      0.000       0.106       0.183
# LgSUBTLWF:Length     0.0362      0.021      1.734      0.083      -0.005       0.077
# LgSUBTLWF:OLD       -0.0689      0.021     -3.222      0.001      -0.111      -0.027
# n_communities        0.0178      0.009      1.963      0.050    2.02e-05       0.036
# ==============================================================================
# Omnibus:                      131.297   Durbin-Watson:                   1.837
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              138.773
# Skew:                           0.340   Prob(JB):                     7.34e-31
# Kurtosis:                       3.162   Cond. No.                         5.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# --------------------------------------------------------------------
# Covariate: entropy
# Likelihood Ratio Test Statistic (p-value)': 14.1 (0.000)
# AIC: 15341
# BIC: 15389
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.445
# Method:                 Least Squares   F-statistic:                     910.0
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:18:25   Log-Likelihood:                -7663.4
# No. Observations:                6815   AIC:                         1.534e+04
# Df Residuals:                    6808   BIC:                         1.539e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0120      0.010     -1.247      0.212      -0.031       0.007
# Length               0.2721      0.019     14.235      0.000       0.235       0.310
# LgSUBTLWF           -0.4076      0.010    -39.451      0.000      -0.428      -0.387
# OLD                  0.1450      0.020      7.424      0.000       0.107       0.183
# LgSUBTLWF:Length     0.0352      0.021      1.691      0.091      -0.006       0.076
# LgSUBTLWF:OLD       -0.0689      0.021     -3.226      0.001      -0.111      -0.027
# entropy              0.0344      0.009      3.753      0.000       0.016       0.052
# ==============================================================================
# Omnibus:                      131.739   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              139.271
# Skew:                           0.341   Prob(JB):                     5.72e-31
# Kurtosis:                       3.163   Cond. No.                         5.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# --------------------------------------------------------------------
# Covariate: max_dom
# Likelihood Ratio Test Statistic (p-value)': 6.7 (0.010)
# AIC: 15348
# BIC: 15396
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     907.8
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:18:25   Log-Likelihood:                -7667.1
# No. Observations:                6815   AIC:                         1.535e+04
# Df Residuals:                    6808   BIC:                         1.540e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0118      0.010     -1.230      0.219      -0.031       0.007
# Length               0.2726      0.019     14.238      0.000       0.235       0.310
# LgSUBTLWF           -0.4092      0.010    -39.602      0.000      -0.429      -0.389
# OLD                  0.1448      0.020      7.403      0.000       0.106       0.183
# LgSUBTLWF:Length     0.0359      0.021      1.721      0.085      -0.005       0.077
# LgSUBTLWF:OLD       -0.0691      0.021     -3.230      0.001      -0.111      -0.027
# max_dom             -0.0238      0.009     -2.587      0.010      -0.042      -0.006
# ==============================================================================
# Omnibus:                      131.852   Durbin-Watson:                   1.837
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              139.401
# Skew:                           0.341   Prob(JB):                     5.36e-31
# Kurtosis:                       3.163   Cond. No.                         5.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# --------------------------------------------------------------------
# Covariate: dissimilarity
# Likelihood Ratio Test Statistic (p-value)': 5.8 (0.016)
# AIC: 15349
# BIC: 15397
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     907.5
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:18:25   Log-Likelihood:                -7667.5
# No. Observations:                6815   AIC:                         1.535e+04
# Df Residuals:                    6808   BIC:                         1.540e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0117      0.010     -1.218      0.223      -0.031       0.007
# Length               0.2756      0.019     14.429      0.000       0.238       0.313
# LgSUBTLWF           -0.4106      0.010    -39.921      0.000      -0.431      -0.390
# OLD                  0.1444      0.020      7.387      0.000       0.106       0.183
# LgSUBTLWF:Length     0.0359      0.021      1.724      0.085      -0.005       0.077
# LgSUBTLWF:OLD       -0.0688      0.021     -3.217      0.001      -0.111      -0.027
# dissimilarity        0.0218      0.009      2.398      0.017       0.004       0.040
# ==============================================================================
# Omnibus:                      130.145   Durbin-Watson:                   1.837
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              137.438
# Skew:                           0.339   Prob(JB):                     1.43e-30
# Kurtosis:                       3.155   Cond. No.                         5.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# --------------------------------------------------------------------
# Covariate: ambiguity_binary
# Likelihood Ratio Test Statistic (p-value)': 9.0 (0.003)
# AIC: 15346
# BIC: 15394
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     908.5
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:18:25   Log-Likelihood:                -7665.9
# No. Observations:                6815   AIC:                         1.535e+04
# Df Residuals:                    6808   BIC:                         1.539e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0117      0.010     -1.215      0.224      -0.031       0.007
# Length               0.2749      0.019     14.395      0.000       0.237       0.312
# LgSUBTLWF           -0.4100      0.010    -39.865      0.000      -0.430      -0.390
# OLD                  0.1438      0.020      7.362      0.000       0.106       0.182
# LgSUBTLWF:Length     0.0361      0.021      1.733      0.083      -0.005       0.077
# LgSUBTLWF:OLD       -0.0689      0.021     -3.221      0.001      -0.111      -0.027
# ambiguity_binary     0.0273      0.009      3.005      0.003       0.009       0.045
# ==============================================================================
# Omnibus:                      130.877   Durbin-Watson:                   1.837
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              138.266
# Skew:                           0.340   Prob(JB):                     9.46e-31
# Kurtosis:                       3.157   Cond. No.                         5.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# --------------------------------------------------------------------
# Covariate: ambiguity
# Likelihood Ratio Test Statistic (p-value)': 10.5 (0.001)
# AIC: 15344
# BIC: 15392
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     908.9
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:18:25   Log-Likelihood:                -7665.2
# No. Observations:                6815   AIC:                         1.534e+04
# Df Residuals:                    6808   BIC:                         1.539e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0120      0.010     -1.247      0.212      -0.031       0.007
# Length               0.2729      0.019     14.278      0.000       0.235       0.310
# LgSUBTLWF           -0.4084      0.010    -39.534      0.000      -0.429      -0.388
# OLD                  0.1456      0.020      7.449      0.000       0.107       0.184
# LgSUBTLWF:Length     0.0350      0.021      1.679      0.093      -0.006       0.076
# LgSUBTLWF:OLD       -0.0687      0.021     -3.215      0.001      -0.111      -0.027
# ambiguity            0.0296      0.009      3.234      0.001       0.012       0.048
# ==============================================================================
# Omnibus:                      131.119   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              138.559
# Skew:                           0.340   Prob(JB):                     8.17e-31
# Kurtosis:                       3.160   Cond. No.                         5.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# RIOPLATENSE SPANISH
# ----------------------------------------------------------------------------------------------------
# load df
df_RP = pd.read_csv('./data/regression_data_RP.csv')

# define baselines and covariates studied
BASELINE_RP = '1 + log_frq + num_letters + Lev_N + log_frq:num_letters + log_frq:Lev_N'
COVARIATES = ['n_communities', 'entropy', 'max_dom', 'dissimilarity', 'ambiguity_binary', 'ambiguity']

# baseline
baseline_formula = 'log_rt ~ ' + BASELINE_RP
preprocessed_df = pre_process(df_RP, ['log_rt', 'log_frq', 'num_letters', 'Lev_N'])
baseline_model = smf.ols(baseline_formula, data=preprocessed_df).fit()

report = f"""
--------------------------------------------------------------------
Covariate: None (Baseline model)
Likelihood Ratio Test Statistic (p-value)': N/A
AIC: {baseline_model.aic:.0f}
BIC: {baseline_model.bic:.0f}
--------------------------------------------------------------------
"""
print(report)
print(baseline_model.summary())
print('\n\n')

for covariate in COVARIATES:
    preprocessed_df = pre_process(df_RP, ['log_rt', 'log_frq', 'num_letters', 'Lev_N', covariate])
    
    # expanded: baseline + covariate
    expanded_formula = 'log_rt ~ ' + BASELINE_RP + ' + ' + covariate
    expanded_model = smf.ols(expanded_formula, data=preprocessed_df).fit()

    lr_stat = 2 * (expanded_model.llf - baseline_model.llf)
    dof = 1 # difference between expanded and baseline model is 1 covariate
    p_value = 1 - stats.chi2.cdf(lr_stat, dof)

    report = f"""
--------------------------------------------------------------------
Covariate: {covariate}
Likelihood Ratio Test Statistic (p-value)': {lr_stat:.1f} ({p_value:.3f})
AIC: {expanded_model.aic:.0f}
BIC: {expanded_model.bic:.0f}
--------------------------------------------------------------------
        """
    print(report)
    print(expanded_model.summary())
    print('\n\n')
# Out:
# --------------------------------------------------------------------
# Covariate: None (Baseline model)
# Likelihood Ratio Test Statistic (p-value)': N/A
# AIC: 16546
# BIC: 16587
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.417
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     1030.
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:23:28   Log-Likelihood:                -8266.9
# No. Observations:                7196   AIC:                         1.655e+04
# Df Residuals:                    7190   BIC:                         1.659e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.0150      0.009     -1.644      0.100      -0.033       0.003
# log_frq                -0.5400      0.009    -57.143      0.000      -0.558      -0.521
# num_letters             0.2845      0.014     20.955      0.000       0.258       0.311
# Lev_N                   0.0125      0.014      0.918      0.359      -0.014       0.039
# log_frq:num_letters    -0.0349      0.014     -2.579      0.010      -0.061      -0.008
# log_frq:Lev_N          -0.0571      0.015     -3.897      0.000      -0.086      -0.028
# ==============================================================================
# Omnibus:                     1258.340   Durbin-Watson:                   1.723
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2609.534
# Skew:                           1.040   Prob(JB):                         0.00
# Kurtosis:                       5.091   Cond. No.                         3.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# --------------------------------------------------------------------
# Covariate: n_communities
# Likelihood Ratio Test Statistic (p-value)': 2.2 (0.136)
# AIC: 16546
# BIC: 16594
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     859.0
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:23:28   Log-Likelihood:                -8265.8
# No. Observations:                7196   AIC:                         1.655e+04
# Df Residuals:                    7189   BIC:                         1.659e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.0151      0.009     -1.651      0.099      -0.033       0.003
# log_frq                -0.5391      0.009    -56.960      0.000      -0.558      -0.521
# num_letters             0.2844      0.014     20.946      0.000       0.258       0.311
# Lev_N                   0.0125      0.014      0.917      0.359      -0.014       0.039
# log_frq:num_letters    -0.0347      0.014     -2.566      0.010      -0.061      -0.008
# log_frq:Lev_N          -0.0578      0.015     -3.937      0.000      -0.087      -0.029
# n_communities           0.0135      0.009      1.490      0.136      -0.004       0.031
# ==============================================================================
# Omnibus:                     1257.877   Durbin-Watson:                   1.723
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2609.505
# Skew:                           1.040   Prob(JB):                         0.00
# Kurtosis:                       5.092   Cond. No.                         3.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# --------------------------------------------------------------------
# Covariate: entropy
# Likelihood Ratio Test Statistic (p-value)': 4.6 (0.031)
# AIC: 16543
# BIC: 16591
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     859.7
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:23:28   Log-Likelihood:                -8264.6
# No. Observations:                7196   AIC:                         1.654e+04
# Df Residuals:                    7189   BIC:                         1.659e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.0151      0.009     -1.650      0.099      -0.033       0.003
# log_frq                -0.5383      0.009    -56.795      0.000      -0.557      -0.520
# num_letters             0.2844      0.014     20.956      0.000       0.258       0.311
# Lev_N                   0.0125      0.014      0.920      0.358      -0.014       0.039
# log_frq:num_letters    -0.0345      0.014     -2.550      0.011      -0.061      -0.008
# log_frq:Lev_N          -0.0580      0.015     -3.953      0.000      -0.087      -0.029
# entropy                 0.0195      0.009      2.154      0.031       0.002       0.037
# ==============================================================================
# Omnibus:                     1257.517   Durbin-Watson:                   1.723
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2610.857
# Skew:                           1.039   Prob(JB):                         0.00
# Kurtosis:                       5.095   Cond. No.                         3.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# --------------------------------------------------------------------
# Covariate: max_dom
# Likelihood Ratio Test Statistic (p-value)': 1.7 (0.187)
# AIC: 16546
# BIC: 16594
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     858.9
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:23:28   Log-Likelihood:                -8266.0
# No. Observations:                7196   AIC:                         1.655e+04
# Df Residuals:                    7189   BIC:                         1.659e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.0151      0.009     -1.648      0.099      -0.033       0.003
# log_frq                -0.5391      0.009    -56.935      0.000      -0.558      -0.521
# num_letters             0.2842      0.014     20.931      0.000       0.258       0.311
# Lev_N                   0.0127      0.014      0.931      0.352      -0.014       0.039
# log_frq:num_letters    -0.0347      0.014     -2.567      0.010      -0.061      -0.008
# log_frq:Lev_N          -0.0576      0.015     -3.925      0.000      -0.086      -0.029
# max_dom                -0.0119      0.009     -1.320      0.187      -0.030       0.006
# ==============================================================================
# Omnibus:                     1258.109   Durbin-Watson:                   1.723
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2610.673
# Skew:                           1.040   Prob(JB):                         0.00
# Kurtosis:                       5.093   Cond. No.                         3.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# --------------------------------------------------------------------
# Covariate: dissimilarity
# Likelihood Ratio Test Statistic (p-value)': 5.5 (0.019)
# AIC: 16542
# BIC: 16590
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     860.0
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:23:28   Log-Likelihood:                -8264.1
# No. Observations:                7196   AIC:                         1.654e+04
# Df Residuals:                    7189   BIC:                         1.659e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.0151      0.009     -1.652      0.099      -0.033       0.003
# log_frq                -0.5387      0.009    -56.928      0.000      -0.557      -0.520
# num_letters             0.2849      0.014     20.989      0.000       0.258       0.312
# Lev_N                   0.0124      0.014      0.910      0.363      -0.014       0.039
# log_frq:num_letters    -0.0345      0.014     -2.554      0.011      -0.061      -0.008
# log_frq:Lev_N          -0.0580      0.015     -3.955      0.000      -0.087      -0.029
# dissimilarity           0.0212      0.009      2.351      0.019       0.004       0.039
# ==============================================================================
# Omnibus:                     1257.541   Durbin-Watson:                   1.724
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2607.181
# Skew:                           1.040   Prob(JB):                         0.00
# Kurtosis:                       5.091   Cond. No.                         3.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# --------------------------------------------------------------------
# Covariate: ambiguity_binary
# Likelihood Ratio Test Statistic (p-value)': 7.7 (0.006)
# AIC: 16540
# BIC: 16588
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.418
# Method:                 Least Squares   F-statistic:                     860.6
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:23:28   Log-Likelihood:                -8263.1
# No. Observations:                7196   AIC:                         1.654e+04
# Df Residuals:                    7189   BIC:                         1.659e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.0151      0.009     -1.653      0.098      -0.033       0.003
# log_frq                -0.5377      0.009    -56.731      0.000      -0.556      -0.519
# num_letters             0.2849      0.014     20.995      0.000       0.258       0.312
# Lev_N                   0.0122      0.014      0.895      0.371      -0.015       0.039
# log_frq:num_letters    -0.0343      0.014     -2.537      0.011      -0.061      -0.008
# log_frq:Lev_N          -0.0583      0.015     -3.978      0.000      -0.087      -0.030
# ambiguity_binary        0.0250      0.009      2.767      0.006       0.007       0.043
# ==============================================================================
# Omnibus:                     1256.288   Durbin-Watson:                   1.724
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2607.180
# Skew:                           1.038   Prob(JB):                         0.00
# Kurtosis:                       5.093   Cond. No.                         3.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# --------------------------------------------------------------------
# Covariate: ambiguity
# Likelihood Ratio Test Statistic (p-value)': 3.4 (0.064)
# AIC: 16544
# BIC: 16593
# --------------------------------------------------------------------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 log_rt   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     859.4
# Date:                Mon, 28 Jul 2025   Prob (F-statistic):               0.00
# Time:                        12:23:28   Log-Likelihood:                -8265.2
# No. Observations:                7196   AIC:                         1.654e+04
# Df Residuals:                    7189   BIC:                         1.659e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.0151      0.009     -1.650      0.099      -0.033       0.003
# log_frq                -0.5390      0.009    -56.966      0.000      -0.558      -0.520
# num_letters             0.2845      0.014     20.960      0.000       0.258       0.311
# Lev_N                   0.0126      0.014      0.927      0.354      -0.014       0.039
# log_frq:num_letters    -0.0346      0.014     -2.562      0.010      -0.061      -0.008
# log_frq:Lev_N          -0.0578      0.015     -3.939      0.000      -0.087      -0.029
# ambiguity               0.0167      0.009      1.849      0.065      -0.001       0.034
# ==============================================================================
# Omnibus:                     1258.201   Durbin-Watson:                   1.723
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2609.916
# Skew:                           1.040   Prob(JB):                         0.00
# Kurtosis:                       5.092   Cond. No.                         3.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
